# %%
import pandas as pd 
import numpy as np 
import matplotlisnb.pyplot as plt 
import seaborn as sns

# %%
temp_df = pd.read_csv('../dataset/Social_Network_Ads.csv')
df = temp_df.iloc[:,2:]

# %%
df.to_csv("social_networking_ads_column_filtered.csv",index=False)

# %%
df = pd.read_csv("./social_networking_ads_column_filtered.csv")
df.isna().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.drop(columns="EstimatedSalary",inplace=True)

# %%
df
# Out:
#      Age  Purchased
# 0     19          0
# 1     35          0
# 2     26          0
# 3     27          0
# 4     19          0
# ..   ...        ...
# 395   46          1
# 396   51          1
# 397   50          1
# 398   36          0
# 399   49          1
#
# [400 rows x 2 columns]

# %%
sns.scatterplot(x="Age",y="Purchased",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Purchased'>

# %%
x = df[["Age"]]
y = df["Purchased"]

from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9125

# %%
df.tail()
# Out:
#      Age  Purchased
# 395   46          1
# 396   51          1
# 397   50          1
# 398   36          0
# 399   49          1

# %%
lr.predict([[46]])
# Out:
# c:\Users\DELL\.conda\envs\pandasNumpyMatplotlibPrac\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
sns.scatterplot(x="Age",y="Purchased",data=df)
sns.lineplot(x="Age",y=lr.predict(x),data=df)
plt.show()
