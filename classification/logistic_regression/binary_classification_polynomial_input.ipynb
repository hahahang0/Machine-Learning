# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("../dataset/binary_polynomial_classification.csv")
df.head()
# Out:
#          x1        x2  output
# 0  3.745401  0.314292       0
# 1  9.507143  6.364104       1
# 2  7.319939  3.143560       1
# 3  5.986585  5.085707       1
# 4  1.560186  9.075665       1

# %%
sns.scatterplot(x="x1",y="x2",data=df,hue=df['output'])
plt.legend(loc="best")
plt.show()

# %%
x  = df.iloc[:,:-1]
y = df["output"]

# %%
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# lr = LogisticRegression()

# %%
# lr.fit(x_train,y_train)

# %%
# lr.score(x_test,y_test)

# %%
# from mlxtend.plotting import plot_decision_regions

# %%
# plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
# # plt.legend(loc="best")
# plt.show()

# %% [markdown]
# Now Using Polynomail Feature

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=2)

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
pf.fit(x)
x = pd.DataFrame(pf.transform(x))



# x = pd.DataFrame(pf.transform(x),columns=x.columns)

# %%
x
# Out:
#       0         1         2          3          4          5
# 0   1.0  3.745401  0.314292  14.028030   1.177149   0.098779
# 1   1.0  9.507143  6.364104  90.385769  60.504448  40.501821
# 2   1.0  7.319939  3.143560  53.581513  23.010667   9.881968
# 3   1.0  5.986585  5.085707  35.839198  30.446016  25.864415
# 4   1.0  1.560186  9.075665   2.434182  14.159729  82.367690
# ..  ...       ...       ...        ...        ...        ...
# 95  1.0  4.937956  3.492096  24.383409  17.243815  12.194733
# 96  1.0  5.227328  7.259557  27.324961  37.948087  52.701165
# 97  1.0  4.275410  8.971103  18.279132  38.355143  80.480682
# 98  1.0  0.254191  8.870864   0.064613   2.254896  78.692232
# 99  1.0  1.078914  7.798755   1.164056   8.414189  60.820587
#
# [100 rows x 6 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       0         1         2          3          4          5
# 55  1.0  9.218742  2.420553  84.985211  22.314452   5.859075
# 88  1.0  8.872127  5.296506  78.714645  46.991274  28.052974
# 26  1.0  1.996738  8.180148   3.986962  16.333610  66.914816
# 42  1.0  0.343885  4.972485   0.118257   1.709964  24.725608
# 69  1.0  9.868869  5.908929  97.394583  58.314453  34.915447
# ..  ...       ...       ...        ...        ...        ...
# 60  1.0  3.886773  3.677831  15.107004  14.294895  13.526443
# 71  1.0  1.987157  0.165878   3.948792   0.329626   0.027516
# 14  1.0  1.818250  6.334038   3.306032  11.516862  40.120032
# 92  1.0  7.607850  9.004181  57.879389  68.502460  81.075268
# 51  1.0  7.751328  2.395619  60.083089  18.569228   5.738990
#
# [80 rows x 6 columns]

# %%
y_train
# Out:
# 55    1
# 88    1
# 26    1
# 42    0
# 69    1
#      ..
# 60    0
# 71    0
# 14    0
# 92    1
# 51    1
# Name: output, Length: 80, dtype: int64

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 1.0
