# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC,SVR
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv("../dataset/polynomial_classification_data.csv")

# %%
df.head()
# Out:
#    Feature1  Feature2  Class
# 0 -1.003679 -2.518937      1
# 1  3.605714  0.335208      1
# 2  1.855952  2.983567      1
# 3  0.789268  1.857799      0
# 4 -2.751851  2.452489      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Temperature (°C)         49 non-null     float64
#  1   Ice Cream Sales (units)  49 non-null     float64
# dtypes: float64(2)
# memory usage: 912.0 bytes

# %%
sns.scatterplot(
    x="Feature1",
    y="Feature2",
    hue="Class",  # Color by temperature
    # Adjust the size range
    data=df,
    palette="viridis"  # Color palette
)
# Out:
# <Axes: xlabel='Feature1', ylabel='Feature2'>

# %%
df.head()
# Out:
#    Feature1  Feature2  Class
# 0 -1.003679 -2.518937      1
# 1  3.605714  0.335208      1
# 2  1.855952  2.983567      1
# 3  0.789268  1.857799      0
# 4 -2.751851  2.452489      1

# %%
x = df.iloc[:,:-1]
y = df["Class"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
svm = SVC(kernel="rbf",C=1,gamma=2)
svm2 = SVC(kernel="poly")

# %%
svm.fit(x_train,y_train)
svm2.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
print(svm.score(x_test,y_test))
print(svm2.score(x_test,y_test))
# Out:
# 1.0
# 0.705

# %%
print(svm.score(x_train,y_train))
print(svm2.score(x_train,y_train))
# Out:
# 0.9875
# 0.715

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=svm,legend=2)
# Out:
# c:\Users\DELL\.conda\envs\pandasNumpyMatplotlibPrac\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=svm2,legend=2)
# Out:
# c:\Users\DELL\.conda\envs\pandasNumpyMatplotlibPrac\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >
